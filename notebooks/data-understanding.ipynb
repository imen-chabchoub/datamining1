# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

data = pd.read_csv("D:/imen-chabchoub/FAC/BDIA2-2/data-mining/datamining1/data/raw/mobile-data.csv")

# %%
print(data.head())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
print(data.columns)
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='str')

# %%
print("Shape:", data.shape)
print(data.info())
# Out:
# Shape: (2000, 21)
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
# ...

# %%
 #Vérifier les valeurs uniques
for col in data.columns:
    print(f"\n{col}")
    print(data[col].value_counts().head(10))
# Out:
# battery_power
# battery_power
# 1589    6
# 618     6
# 1872    6
# 772     5
# 1949    5
# 1310    5
# 1063    5
# 1083    5
# 832     5
# 1379    5
# Name: count, dtype: int64
#
# blue
# blue
# 0    1010
# 1     990
# Name: count, dtype: int64
#
# clock_speed
# clock_speed
# 0.5    413
# 2.8     85
# 2.3     78
# 2.1     76
# 1.6     76
# 2.5     74
# 0.6     74
# 1.4     70
# 1.3     68
# 2.0     67
# Name: count, dtype: int64
#
# dual_sim
# dual_sim
# 1    1019
# 0     981
# Name: count, dtype: int64
#
# fc
# fc
# 0    474
# 1    245
# 2    189
# 3    170
# 5    139
# 4    133
# 6    112
# 7    100
# 9     78
# 8     77
# Name: count, dtype: int64
#
# four_g
# four_g
# 1    1043
# 0     957
# Name: count, dtype: int64
#
# int_memory
# int_memory
# 27    47
# 14    45
# 16    45
# 57    42
# 2     42
# 7     40
# 42    40
# 44    39
# 30    39
# 8     37
# Name: count, dtype: int64
#
# m_dep
# m_dep
# 0.1    320
# 0.2    213
# 0.8    208
# 0.5    205
# 0.7    200
# 0.3    199
# ...

# %%
#les valeurs manquantes 
missing = data.isnull().sum()
print(missing)

# en pourcentage
missing_percent = (missing / len(data)) * 100
print(missing_percent)
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
# battery_power    0.0
# blue             0.0
# clock_speed      0.0
# dual_sim         0.0
# fc               0.0
# four_g           0.0
# int_memory       0.0
# m_dep            0.0
# mobile_wt        0.0
# n_cores          0.0
# pc               0.0
# px_height        0.0
# px_width         0.0
# ram              0.0
# sc_h             0.0
# sc_w             0.0
# talk_time        0.0
# three_g          0.0
# touch_screen     0.0
# wifi             0.0
# price_range      0.0
# dtype: float64

# %%
#Statistiques avancées
print(data.describe(include='all'))
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
print(data['int_memory'].value_counts())
# Out:
# int_memory
# 27    47
# 14    45
# 16    45
# 57    42
# 2     42
#       ..
# 37    24
# 38    23
# 62    21
# 4     20
# 59    18
# Name: count, Length: 63, dtype: int64

# %%
print(data['clock_speed'].value_counts())
# Out:
# clock_speed
# 0.5    413
# 2.8     85
# 2.3     78
# 2.1     76
# 1.6     76
# 2.5     74
# 0.6     74
# 1.4     70
# 1.3     68
# 2.0     67
# 1.5     67
# 1.9     65
# 0.7     64
# 2.9     62
# 1.8     62
# 1.0     61
# 1.7     60
# 2.2     59
# 0.9     58
# 2.4     58
# 0.8     58
# 1.2     56
# 2.6     55
# 2.7     55
# 1.1     51
# 3.0     28
# Name: count, dtype: int64

# %%
print(data['pc'].value_counts())
# Out:
# pc
# 10    122
# 7     119
# 9     112
# 20    110
# 14    104
# 1     104
# 0     101
# 2      99
# 17     99
# 6      95
# 4      95
# 3      93
# 15     92
# 12     90
# 8      89
# 16     88
# 13     85
# 19     83
# 18     82
# 11     79
# 5      59
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

data['price_range'].value_counts().plot(kind='bar')
plt.show()

# %%
import seaborn as sns

sns.boxplot(x='price_range', y='battery_power', data=data)
plt.show()

# %%
data = data.reset_index(drop=True)
plt.figure(figsize=(10,5))
sns.countplot(x='fc', hue='price_range', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
cols = ["battery_power", "ram", "px_width", "px_height", "int_memory"]
data[cols].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. sélectionner les colonnes numériques continues (exclure blue, dual_sim, four_g, etc. si tu veux)
num_cols = ["battery_power", "clock_speed", "int_memory", "mobile_wt", "n_cores", 
            "pc", "fc", "px_height", "px_width", "ram", "sc_h", "sc_w", "talk_time"]

corr = data[num_cols].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=False, cmap="coolwarm", center=0)
plt.title("Matrice de corrélation des variables numériques")
plt.show()
